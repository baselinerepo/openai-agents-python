# %% [markdown]
# ## Responses vs. Chat Completions
#
# The Responses API and Chat Completions API are two different ways to interact with OpenAI's models.
#
# ### The Responses API
#
# The Responses API is our newest core API and an agentic API primitive, combining the simplicity of Chat Completions with the ability to do more agentic tasks. As model capabilities evolve, the Responses API is a flexible foundation for building action-oriented applications, with built-in tools:
#
# ## Compare the code
#
# Both APIs make it easy to generate output from our models. A completion requires a messages array, but a response requires an input (string or array, as shown below).
#
# ### Chat Completions API - Text generation sample

# %%
from openai import OpenAI
from dotenv import load_dotenv

# load environment variables
load_dotenv()

# Initialize the OpenAI client with the API key
gpt_client = OpenAI()

# define model constants
GPT_MODEL = "gpt-4o-mini"

completion = gpt_client.chat.completions.create(
    model=GPT_MODEL,
    messages=[
        {
            "role": "user",
            "content": "Write a one-sentence bedtime story about a unicorn.",
        }
    ]
)
print(f"{completion}\n")
print(completion.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-BpsHS8B6sAt21eDb3FrsJlW4tH1Zt', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='As the moonlight shimmered on the enchanted meadow, a gentle unicorn with a golden horn danced with fireflies, spreading dreams of hope and magic to all who slept.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1751703082, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=34, prompt_tokens=18, total_tokens=52, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
#
# As the moonlight shimmered on the enchanted meadow, a gentle unicorn with a golden horn danced with fireflies, spreading dreams of hope and magic to all who slept.

# %% [markdown]
# ### Responses API - Text generation sample

# %%
from openai import OpenAI
from dotenv import load_dotenv
import json

# load environment variables
load_dotenv()

# Initialize the OpenAI client with the API key
gpt_client = OpenAI()

# define model constants
GPT_MODEL = "gpt-4o-mini"

response = gpt_client.responses.create(
    model=GPT_MODEL,
    input=[
        {
            "role": "user",
            "content": "Write a one-sentence bedtime story about a unicorn.",
        }
    ]
)
print(f"{response}\n")
print(response.output_text)
# Out:
# Response(id='resp_6868de238e8881a18ca9274784164e9b075d07655c0f0d13', created_at=1751703075.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[ResponseOutputMessage(id='msg_6868de23ce5481a18719246c57db2296075d07655c0f0d13', content=[ResponseOutputText(annotations=[], text='As the moonlight danced on the sparkling lake, a gentle unicorn named Luna made a wish, sending a cascade of shimmering stars into the night sky to grant sweet dreams to all the creatures in the forest.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, max_output_tokens=None, previous_response_id=None, prompt=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=ResponseUsage(input_tokens=18, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=42, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=60), user=None, max_tool_calls=None, store=True, top_logprobs=0)
#
# As the moonlight danced on the sparkling lake, a gentle unicorn named Luna made a wish, sending a cascade of shimmering stars into the night sky to grant sweet dreams to all the creatures in the forest.

# %% [markdown]
# When you get a response back from the Responses API, the fields differ slightly. Instead of a message, you receive a typed response object with its own id. Responses are stored by default. Chat completions are stored by default for new accounts. To disable storage when using either API, set store: false

# %% [markdown]
# **Other noteworthy differences**
#
# - The Responses API returns output, while the Chat Completions API returns a choices array.
# - Structured Outputs API shape is different. Instead of response_format, use text.format in Responses. Learn more in the Structured Outputs guide.
# - Function calling API shape is different—both for the function config on the request and function calls sent back in the response. See the full difference in the function calling guide.
# - Reasoning is different. Instead of reasoning_effort in Chat Completions, use reasoning.effort with the Responses API. Read more details in the reasoning guide.
# - The Responses SDK has an output_text helper, which the Chat Completions SDK does not have.
# - Conversation state: You have to manage conversation state yourself in Chat Completions, while Responses has previous_response_id to help you with long-running conversations.
# - Responses are stored by default. Chat completions are stored by default for new accounts. To disable storage, set store: false.
